# %% [markdown]
# # Weather Data Preprocessing

# %% [markdown]
# ## Set up

# %%
# %matplotlib inline

import logging
import itertools
import json
import os
import pickle
import urllib2
import folium
import time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from mpl_toolkits.basemap import Basemap
from datetime import datetime
from os import listdir
from os.path import isfile, join
from src.data.parse_dataset import parse_json_files, parse_json_file, get_file_list, parse_dir
from IPython.display import Image
from datetime import date

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Single Weather Station Approach

# %% [markdown]
# Set the time period for which data will be collected

# %%
start_date = date(2016, 5, 16)
end_date = date(2016, 6, 13)

days = pd.date_range(start=start_date, end=end_date, closed='left')

# %% [markdown]
# Download the data from Wunderground

# %%
def download(url_string, file_name):
    """Download the given resource to the given file"""
    
    response = urllib2.urlopen(url_string)
    with open(file_name, "wb") as f:
        f.write(response.read())

# %%
path = '/home/jfconavarrete/Documents/Work/Dissertation/spts-uoe/data/raw/weather'
lhr_url = 'http://api.wunderground.com/api/8494fbcae3235601/history_%s/q/UK/London.json'

# iterate through all days and stations
for i,day in enumerate(days):
    url_string = lhr_url % (day.strftime('%Y%m%d'))
    file_name = '%s/WEATHER-%s.json' % (path, day.strftime('%Y-%m-%d'))
    
    logger.info('Downloading %s', url_string)
    download(url_string, file_name)
    
    # sleep 60 seconds every 10 requests due to API restrictions 
    if (i % 10) == 9:
        time.sleep(60)

# %% [markdown]
# ## Data Parsing
#
# Parse the JSON data files

# %%
def parse_weather(json_obj):
    """Parses Wunderground API History JSON response"""
    
    return [parse_observation(element) for element in json_obj['history']['observations']]

def parse_observation(observation):
    """Parses a JSON observation object to a dictionary"""
    
    reading = {
        'Timestamp': observation['utcdate']['pretty'],
        'Temp': observation['tempm'],
        'DewPt': observation['dewptm'],
        'Humidity': observation['hum'],
        'WindSpeed': observation['wspdm'],
        'WindDirD': observation['wdird'],
        'WindDirE': observation['wdire'],
        'Visibility': observation['vism'],
        'Pressure': observation['pressurem'],
        'WindChill': observation['windchillm'],
        'Precipitation': observation['precipm'],
        'Condition': observation['conds'],
        'Fog': observation['fog'],
        'Rain': observation['rain'],
        'Snow': observation['snow'],
        'Hail': observation['hail'],
        'Thunder': observation['thunder'],
        'Tornado': observation['tornado'],
    }

    return reading

# %%
def get_file_date(file_name):
    """Gets the file's date"""
    
    file_basename = os.path.basename(file_name)
    idx = file_basename.find('-')
    file_date = file_basename[idx + 1:]
    return datetime.strptime(file_date, '%Y-%m-%d.json')

# %% [markdown]
# Convert the raw data to a Pandas DataFrame

# %%
records = parse_dir('/home/jfconavarrete/Documents/Work/Dissertation/spts-uoe/data/raw/weather', 
                    parse_weather, sort_fn=get_file_date)

weather_dataset = pd.DataFrame(list(itertools.chain.from_iterable(records)))

# %% [markdown]
# ## Technically Correct Data

# %%
# replace missing values
replace_empty = lambda col: col.replace('T', np.nan).replace('N/A', np.nan).replace('', np.nan)
replace_na = lambda col: col.replace('-9999.00', np.nan).replace('-9999', np.nan).replace('-9999.0', np.nan).replace('-999', np.nan)
weather_dataset = weather_dataset.apply(replace_empty, axis=1).apply(replace_na, axis=1)

# convert columns to their appropriate datatypes
weather_dataset['Fog'] = weather_dataset['Fog'].astype('bool_')
weather_dataset['Hail'] = weather_dataset['Hail'].astype('bool_')
weather_dataset['Rain'] = weather_dataset['Rain'].astype('bool_')
weather_dataset['Snow'] = weather_dataset['Snow'].astype('bool_')
weather_dataset['Tornado'] = weather_dataset['Tornado'].astype('bool_')
weather_dataset['Thunder'] = weather_dataset['Snow'].astype('bool_')

weather_dataset['Precipitation'] = weather_dataset['Precipitation'].astype('float32')
weather_dataset['Visibility'] = weather_dataset['Visibility'].astype('float32')
weather_dataset['WindChill'] = weather_dataset['WindChill'].astype('float32')
weather_dataset['WindSpeed'] = weather_dataset['WindSpeed'].astype('float32')
weather_dataset['DewPt'] = weather_dataset['DewPt'].astype('float32')
weather_dataset['Humidity'] = weather_dataset['Humidity'].astype('float32')
weather_dataset['Pressure'] = weather_dataset['Pressure'].astype('float32')
weather_dataset['Temp'] = weather_dataset['Temp'].astype('float32')
weather_dataset['WindDirD'] = weather_dataset['WindDirD'].astype('float32')

weather_dataset['Timestamp'] =  pd.to_datetime(weather_dataset['Timestamp'], format='%I:%M %p %Z on %B %d, %Y', errors='raise')

# %%
weather_dataset.sort_values(by=['Timestamp'], inplace=True)

# %%
def expand_datetime(df, datetime_col):
    df['Weekday'] = df[datetime_col].apply(lambda x: x.dayofweek) # Monday=0, Sunday=6
    df['Minute'] = df[datetime_col].apply(lambda x: x.minute)
    df['Hour'] = df[datetime_col].apply(lambda x: x.hour)
    return df

expand_datetime(weather_dataset, 'Timestamp')
# Out:
#              Condition  DewPt   Fog  Hail  Humidity  Precipitation  Pressure  \
# 0             Overcast    8.0  True  True      71.0            NaN    1022.0
# 1        Mostly Cloudy    7.0  True  True      72.0            NaN    1021.0
# 2              Unknown    8.0  True  True      82.0            NaN    1021.0
# 3        Mostly Cloudy    8.0  True  True      77.0            NaN    1022.0
# 4              Unknown    8.0  True  True      82.0            NaN    1021.0
# 5              Unknown    8.0  True  True      82.0            NaN    1021.0
# 6        Mostly Cloudy    8.0  True  True      77.0            NaN    1022.0
# 7              Unknown    7.0  True  True      82.0            NaN    1021.0
# 8              Unknown    8.0  True  True      87.0            NaN    1021.0
# 9     Scattered Clouds    8.0  True  True      84.0            NaN    1021.0
# 10             Unknown    7.0  True  True      82.0            NaN    1021.0
# 11             Unknown    7.0  True  True      82.0            NaN    1021.0
# 12    Scattered Clouds    8.0  True  True      87.0            NaN    1021.0
# 13             Unknown    7.0  True  True      87.0            NaN    1021.0
# 14             Unknown    7.0  True  True      87.0            NaN    1021.0
# 15                 NaN    8.0  True  True      92.0            NaN    1021.0
# 16             Unknown    7.0  True  True      93.0            NaN    1021.0
# 17             Unknown    7.0  True  True      93.0            NaN    1021.0
# 18                 NaN    7.0  True  True      92.0            NaN    1021.0
# 19       Partly Cloudy    7.0  True  True      93.0            NaN    1021.0
# 20             Unknown    7.0  True  True      87.0            NaN    1021.0
# 21                 NaN    8.0  True  True      83.0            NaN    1022.0
# 22       Partly Cloudy    7.0  True  True      82.0            NaN    1021.0
# 23       Partly Cloudy    7.0  True  True      82.0            NaN    1021.0
# 24    Scattered Clouds    8.0  True  True      77.0            NaN    1022.0
# 25       Partly Cloudy    7.0  True  True      76.0            NaN    1022.0
# 26             Unknown    7.0  True  True      72.0            NaN    1022.0
# 27    Scattered Clouds    7.0  True  True      64.0            NaN    1022.0
# 28             Unknown    6.0  True  True      67.0            NaN    1022.0
# 29             Unknown    6.0  True  True      63.0            NaN    1022.0
# ...                ...    ...   ...   ...       ...            ...       ...
# 1975              Rain   17.0  True  True      96.0            NaN    1007.0
# 1976     Mostly Cloudy   15.0  True  True      83.0            NaN    1006.0
# 1977     Mostly Cloudy   15.0  True  True      78.0            NaN    1006.0
# 1978              Rain   16.0  True  True      69.0            NaN    1006.0
# 1979          Overcast   15.0  True  True      78.0            NaN    1005.0
# 1980          Overcast   16.0  True  True      78.0            NaN    1005.0
# 1981              Rain   17.0  True  True      76.0            NaN    1005.0
# 1982     Mostly Cloudy   16.0  True  True      78.0            NaN    1005.0
# 1983        Light Rain   16.0  True  True      83.0            NaN    1005.0
# 1984        Heavy Rain   17.0  True  True      84.0            NaN    1005.0
# 1985        Light Rain   16.0  True  True      78.0            NaN    1005.0
# 1986        Light Rain   16.0  True  True      83.0            NaN    1004.0
# 1987              Rain   17.0  True  True      85.0            NaN    1005.0
# 1988  Scattered Clouds   16.0  True  True      83.0            NaN    1004.0
# 1989           Unknown   16.0  True  True      83.0            NaN    1004.0
# 1990              Rain   16.0  True  True      77.0            NaN    1004.0
# 1991           Unknown   16.0  True  True      83.0            NaN    1004.0
# 1992     Partly Cloudy   15.0  True  True      78.0            NaN    1004.0
# 1993     Mostly Cloudy   16.0  True  True      79.0            NaN    1004.0
# 1994     Mostly Cloudy   16.0  True  True      83.0            NaN    1004.0
# 1995     Mostly Cloudy   15.0  True  True      83.0            NaN    1004.0
# 1996     Mostly Cloudy   16.0  True  True      79.0            NaN    1004.0
# 1997     Mostly Cloudy   14.0  True  True      77.0            NaN    1004.0
# 1998     Partly Cloudy   14.0  True  True      82.0            NaN    1004.0
# 1999  Scattered Clouds   15.0  True  True      77.0            NaN    1004.0
# 2000     Partly Cloudy   14.0  True  True      82.0            NaN    1004.0
# 2001           Unknown   13.0  True  True      82.0            NaN    1004.0
# 2002  Scattered Clouds   15.0  True  True      80.0            NaN    1005.0
# 2003           Unknown   14.0  True  True      88.0            NaN    1005.0
# 2004           Unknown   14.0  True  True      88.0            NaN    1005.0
#
#       Rain  Snow  Temp  ...            Timestamp Tornado Visibility  \
# 0     True  True  12.0  ...  2016-05-15 23:00:00    True       19.0
# 1     True  True  12.0  ...  2016-05-15 23:20:00    True       10.0
# 2     True  True  11.0  ...  2016-05-15 23:50:00    True       10.0
# 3     True  True  11.0  ...  2016-05-16 00:00:00    True       18.0
# 4     True  True  11.0  ...  2016-05-16 00:20:00    True       10.0
# 5     True  True  11.0  ...  2016-05-16 00:50:00    True       10.0
# 6     True  True  11.0  ...  2016-05-16 01:00:00    True       17.0
# 7     True  True  10.0  ...  2016-05-16 01:20:00    True       10.0
# 8     True  True  10.0  ...  2016-05-16 01:50:00    True       10.0
# 9     True  True  10.0  ...  2016-05-16 02:00:00    True       15.0
# 10    True  True  10.0  ...  2016-05-16 02:20:00    True       10.0
# 11    True  True  10.0  ...  2016-05-16 02:50:00    True       10.0
# 12    True  True   9.0  ...  2016-05-16 03:00:00    True       16.0
# 13    True  True   9.0  ...  2016-05-16 03:20:00    True       10.0
# 14    True  True   9.0  ...  2016-05-16 03:50:00    True       10.0
# 15    True  True   9.0  ...  2016-05-16 04:00:00    True       10.0
# 16    True  True   8.0  ...  2016-05-16 04:20:00    True       10.0
# 17    True  True   8.0  ...  2016-05-16 04:50:00    True        9.0
# 18    True  True   9.0  ...  2016-05-16 05:00:00    True       11.0
# 19    True  True   8.0  ...  2016-05-16 05:20:00    True       10.0
# 20    True  True   9.0  ...  2016-05-16 05:50:00    True       10.0
# 21    True  True  10.0  ...  2016-05-16 06:00:00    True       11.0
# 22    True  True  10.0  ...  2016-05-16 06:20:00    True       10.0
# 23    True  True  10.0  ...  2016-05-16 06:50:00    True       10.0
# 24    True  True  11.0  ...  2016-05-16 07:00:00    True       13.0
# 25    True  True  11.0  ...  2016-05-16 07:20:00    True       10.0
# 26    True  True  12.0  ...  2016-05-16 07:50:00    True       10.0
# 27    True  True  12.0  ...  2016-05-16 08:00:00    True       18.0
# 28    True  True  12.0  ...  2016-05-16 08:20:00    True       10.0
# 29    True  True  13.0  ...  2016-05-16 08:50:00    True       10.0
# ...    ...   ...   ...  ...                  ...     ...        ...
# 1975  True  True  17.0  ...  2016-06-12 13:00:00    True       40.0
# 1976  True  True  18.0  ...  2016-06-12 13:20:00    True       10.0
# 1977  True  True  19.0  ...  2016-06-12 13:50:00    True       10.0
# 1978  True  True  20.0  ...  2016-06-12 14:00:00    True       35.0
# 1979  True  True  19.0  ...  2016-06-12 14:20:00    True       10.0
# 1980  True  True  20.0  ...  2016-06-12 14:50:00    True       10.0
# 1981  True  True  21.0  ...  2016-06-12 15:00:00    True       22.0
# 1982  True  True  20.0  ...  2016-06-12 15:20:00    True       10.0
# 1983  True  True  19.0  ...  2016-06-12 15:50:00    True       10.0
# 1984  True  True  19.0  ...  2016-06-12 16:00:00    True       45.0
# 1985  True  True  20.0  ...  2016-06-12 16:20:00    True       10.0
# 1986  True  True  19.0  ...  2016-06-12 16:50:00    True       10.0
# 1987  True  True  19.0  ...  2016-06-12 17:00:00    True       40.0
# 1988  True  True  19.0  ...  2016-06-12 17:20:00    True       10.0
# 1989  True  True  19.0  ...  2016-06-12 17:50:00    True       10.0
# 1990  True  True  19.0  ...  2016-06-12 18:00:00    True       45.0
# 1991  True  True  19.0  ...  2016-06-12 18:20:00    True       10.0
# 1992  True  True  19.0  ...  2016-06-12 18:50:00    True       10.0
# 1993  True  True  19.0  ...  2016-06-12 19:00:00    True       50.0
# 1994  True  True  19.0  ...  2016-06-12 19:20:00    True       10.0
# 1995  True  True  18.0  ...  2016-06-12 19:50:00    True       10.0
# 1996  True  True  19.0  ...  2016-06-12 20:00:00    True       50.0
# 1997  True  True  18.0  ...  2016-06-12 20:20:00    True       10.0
# 1998  True  True  17.0  ...  2016-06-12 20:50:00    True       10.0
# 1999  True  True  18.0  ...  2016-06-12 21:00:00    True       40.0
# 2000  True  True  17.0  ...  2016-06-12 21:20:00    True       10.0
# 2001  True  True  16.0  ...  2016-06-12 21:50:00    True       10.0
# 2002  True  True  17.0  ...  2016-06-12 22:00:00    True       50.0
# 2003  True  True  16.0  ...  2016-06-12 22:20:00    True       10.0
# 2004  True  True  16.0  ...  2016-06-12 22:50:00    True       10.0
#
#       WindChill  WindDirD  WindDirE  WindSpeed  Weekday  Minute  Hour
# 0           NaN     100.0      East  14.800000        6       0    23
# 1           NaN     120.0       ESE  11.100000        6      20    23
# 2           NaN     120.0       ESE   9.300000        6      50    23
# 3           NaN     120.0       ESE  13.000000        0       0     0
# 4           NaN      80.0      East  11.100000        0      20     0
# 5           NaN      70.0       ENE   9.300000        0      50     0
# 6           NaN      60.0       ENE   9.300000        0       0     1
# 7           NaN      80.0      East   7.400000        0      20     1
# 8           NaN      80.0      East   5.600000        0      50     1
# 9           NaN      80.0      East   5.600000        0       0     2
# 10          NaN      90.0      East   3.700000        0      20     2
# 11          NaN      80.0      East   3.700000        0      50     2
# 12          NaN      80.0      East   5.600000        0       0     3
# 13          NaN      80.0      East   3.700000        0      20     3
# 14          NaN       0.0  Variable   3.700000        0      50     3
# 15          NaN      30.0       NNE   3.700000        0       0     4
# 16          6.8     350.0     North   7.400000        0      20     4
# 17          6.8     360.0     North   7.400000        0      50     4
# 18          NaN      10.0     North   9.300000        0       0     5
# 19          6.8     360.0     North   7.400000        0      20     5
# 20          NaN     350.0     North   9.300000        0      50     5
# 21          NaN      10.0     North   9.300000        0       0     6
# 22          NaN     360.0     North  13.000000        0      20     6
# 23          NaN      20.0       NNE  11.100000        0      50     6
# 24          NaN      20.0       NNE   9.300000        0       0     7
# 25          NaN      30.0       NNE   9.300000        0      20     7
# 26          NaN      20.0       NNE   7.400000        0      50     7
# 27          NaN      20.0       NNE   9.300000        0       0     8
# 28          NaN     350.0     North   7.400000        0      20     8
# 29          NaN     340.0       NNW   9.300000        0      50     8
# ...         ...       ...       ...        ...      ...     ...   ...
# 1975        NaN     230.0        SW  11.100000        6       0    13
# 1976        NaN     240.0       WSW  16.700001        6      20    13
# 1977        NaN     240.0       WSW  14.800000        6      50    13
# 1978        NaN     230.0        SW  13.000000        6       0    14
# 1979        NaN     220.0        SW  13.000000        6      20    14
# 1980        NaN     250.0       WSW  13.000000        6      50    14
# 1981        NaN     240.0       WSW  14.800000        6       0    15
# 1982        NaN     220.0        SW  14.800000        6      20    15
# 1983        NaN     230.0        SW  14.800000        6      50    15
# 1984        NaN     240.0       WSW  14.800000        6       0    16
# 1985        NaN     260.0      West  14.800000        6      20    16
# 1986        NaN     230.0        SW  18.500000        6      50    16
# 1987        NaN     220.0        SW  16.700001        6       0    17
# 1988        NaN     220.0        SW  14.800000        6      20    17
# 1989        NaN     240.0       WSW  16.700001        6      50    17
# 1990        NaN     240.0       WSW  18.500000        6       0    18
# 1991        NaN     240.0       WSW  14.800000        6      20    18
# 1992        NaN     240.0       WSW  13.000000        6      50    18
# 1993        NaN     240.0       WSW  13.000000        6       0    19
# 1994        NaN     250.0       WSW  13.000000        6      20    19
# 1995        NaN     260.0      West  14.800000        6      50    19
# 1996        NaN     260.0      West  13.000000        6       0    20
# 1997        NaN     270.0      West  14.800000        6      20    20
# 1998        NaN     280.0      West  14.800000        6      50    20
# 1999        NaN     270.0      West  13.000000        6       0    21
# 2000        NaN     260.0      West  14.800000        6      20    21
# 2001        NaN     280.0      West  13.000000        6      50    21
# 2002        NaN     270.0      West  11.100000        6       0    22
# 2003        NaN     270.0      West  11.100000        6      20    22
# 2004        NaN     260.0      West  13.000000        6      50    22
#
# [2005 rows x 21 columns]

# %% [markdown]
# ## Consistent Data

# %% [markdown]
# Include data just between 7:00 to 23:00

# %%
weather_dataset = weather_dataset.drop(weather_dataset[(weather_dataset['Hour'] < 7) | (weather_dataset['Hour'] > 22)].index)

# %%
weather_dataset.shape
# Out:
# (1334, 21)

# %%
weather_dataset.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1334 entries, 24 to 2004
# Data columns (total 21 columns):
# Condition        1286 non-null object
# DewPt            1334 non-null float32
# Fog              1334 non-null bool
# Hail             1334 non-null bool
# Humidity         1334 non-null float32
# Precipitation    0 non-null float32
# Pressure         1334 non-null float32
# Rain             1334 non-null bool
# Snow             1334 non-null bool
# Temp             1334 non-null float32
# Thunder          1334 non-null bool
# Timestamp        1334 non-null datetime64[ns]
# Tornado          1334 non-null bool
# Visibility       1331 non-null float32
# WindChill        0 non-null float32
# WindDirD         1334 non-null float32
# WindDirE         1334 non-null object
# WindSpeed        1334 non-null float32
# Weekday          1334 non-null int64
# Minute           1334 non-null int64
# Hour             1334 non-null int64
# dtypes: bool(6), datetime64[ns](1), float32(9), int64(3), object(2)
# memory usage: 334.0 KB

# %%
weather_dataset.head()
# Out:
#            Condition  DewPt   Fog  Hail  Humidity  Precipitation  Pressure  \
# 24  Scattered Clouds    8.0  True  True      77.0            NaN    1022.0
# 25     Partly Cloudy    7.0  True  True      76.0            NaN    1022.0
# 26           Unknown    7.0  True  True      72.0            NaN    1022.0
# 27  Scattered Clouds    7.0  True  True      64.0            NaN    1022.0
# 28           Unknown    6.0  True  True      67.0            NaN    1022.0
#
#     Rain  Snow  Temp  ...            Timestamp Tornado Visibility  WindChill  \
# 24  True  True  11.0  ...  2016-05-16 07:00:00    True       13.0        NaN
# 25  True  True  11.0  ...  2016-05-16 07:20:00    True       10.0        NaN
# 26  True  True  12.0  ...  2016-05-16 07:50:00    True       10.0        NaN
# 27  True  True  12.0  ...  2016-05-16 08:00:00    True       18.0        NaN
# 28  True  True  12.0  ...  2016-05-16 08:20:00    True       10.0        NaN
#
#     WindDirD  WindDirE WindSpeed  Weekday  Minute  Hour
# 24      20.0       NNE       9.3        0       0     7
# 25      30.0       NNE       9.3        0      20     7
# 26      20.0       NNE       7.4        0      50     7
# 27      20.0       NNE       9.3        0       0     8
# 28     350.0     North       7.4        0      20     8
#
# [5 rows x 21 columns]

# %%
weather_dataset.describe()
# Out:
#              DewPt     Humidity  Precipitation     Pressure         Temp  \
# count  1334.000000  1334.000000            0.0  1334.000000  1334.000000
# mean     10.311094    68.200897            NaN  1015.959534    16.035233
# std       3.038621    16.045976            NaN     5.265908     3.459475
# min      -2.000000    21.000000            NaN  1002.000000     9.000000
# 25%       8.000000    56.000000            NaN  1013.000000    13.000000
# 50%      10.000000    72.000000            NaN  1017.000000    16.000000
# 75%      12.000000    82.000000            NaN  1020.000000    18.000000
# max      19.000000   100.000000            NaN  1024.000000    25.000000
#
#         Visibility  WindChill     WindDirD    WindSpeed      Weekday  \
# count  1331.000000        0.0  1334.000000  1334.000000  1334.000000
# mean     14.900301        NaN   152.721146    13.319413     3.001499
# std       9.886402        NaN   125.337108     5.407516     1.998874
# min       3.700000        NaN     0.000000     1.900000     0.000000
# 25%      10.000000        NaN    30.000000     9.300000     1.000000
# 50%      10.000000        NaN   120.000000    13.000000     3.000000
# 75%      15.000000        NaN   260.000000    16.700001     5.000000
# max      50.000000        NaN   360.000000    33.299999     6.000000
#
#             Minute         Hour
# count  1334.000000  1334.000000
# mean     23.470765    14.503748
# std      20.529933     4.619464
# min       0.000000     7.000000
# 25%       0.000000    10.000000
# 50%      20.000000    15.000000
# 75%      50.000000    19.000000
# max      50.000000    22.000000

# %%
weather_dataset.apply(lambda x:x.nunique())
# Out:
# Condition          18
# DewPt              20
# Fog                 1
# Hail                1
# Humidity           75
# Precipitation       0
# Pressure           23
# Rain                1
# Snow                1
# Temp               17
# Thunder             1
# Timestamp        1334
# Tornado             1
# Visibility         35
# WindChill           0
# WindDirD           37
# WindDirE           17
# WindSpeed          17
# Weekday             7
# Minute              3
# Hour               16
# dtype: int64

# %%
weather_dataset.isnull().sum()
# Out:
# Condition          48
# DewPt               0
# Fog                 0
# Hail                0
# Humidity            0
# Precipitation    1334
# Pressure            0
# Rain                0
# Snow                0
# Temp                0
# Thunder             0
# Timestamp           0
# Tornado             0
# Visibility          3
# WindChill        1334
# WindDirD            0
# WindDirE            0
# WindSpeed           0
# Weekday             0
# Minute              0
# Hour                0
# dtype: int64

# %% [markdown]
# ## Build
